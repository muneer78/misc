# %%
import pandas as pd

# %%
df_leads = pd.read_csv("2023-08-17-Day91Leads.csv")
df_leads_old = pd.read_csv("20230815-Day91Leads.csv")

# %%
df_leads = df_leads.sort_values(by=["nk_dotnbr"])
df_leads_old = df_leads_old.sort_values(by=["nk_dotnbr"])

# %%
df_leads.eq(df_leads_old)
# Out:
#      nk_dotnbr  stc_sf_id  stc_contact_id  open_cs_opp_id  \
# 389       True      False           False           False
# 373       True      False           False           False
# 110       True      False           False           False
# 263       True      False           False           False
# 46        True      False           False           False
# ..         ...        ...             ...             ...
# 729       True      False           False           False
# 697       True      False           False           False
# 541       True      False           False           False
# 190       True      False           False           False
# 136       True      False           False           False
#
#      cs_opp_last_activity  cs_opp_owner  stc_sf_name  pfj_sf_name  state  \
# 389                 False         False        False         True   True
# 373                 False         False        False         True   True
# ...

# %%
df_newopps = pd.read_csv("2023-08-17-Day91NewOpps.csv")
df_newopps_old = pd.read_csv("20230815-Day91NewOpps.csv")

# %%
df_newopps = df_newopps.sort_values(by=["nk_dotnbr"])
df_newopps_old = df_newopps.sort_values(by=["nk_dotnbr"])

# %%
df_newopps.eq(df_newopps_old)
# Out:
#      nk_dotnbr  stc_sf_id  stc_contact_id  open_cs_opp_id  \
# 60        True       True            True           False
# 67        True       True            True           False
# 129       True       True            True           False
# 88        True       True            True           False
# 86        True       True            True           False
# ..         ...        ...             ...             ...
# 46        True       True            True           False
# 10        True       True            True           False
# 123       True       True            True           False
# 49        True       True            True           False
# 27        True       True            True           False
#
#      cs_opp_last_activity  cs_opp_owner  stc_sf_name  pfj_sf_name  state  \
# 60                  False         False         True         True   True
# 67                  False         False         True         True   True
# ...
